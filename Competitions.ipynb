# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaeldeflon/Finta_PBI_projects/blob/main/Competitions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Adding the competitions names

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = None
games = pd.read_csv('games1.csv')
games = pd.DataFrame(games)
display(games.head(5))
# Out:
#    Unnamed: 0  game_id competition_code  season          round        date  \
# 0           0  2244388              SUC    2012  final 1st leg  2012-08-22
# 1           1  2219794             BESC    2011          Final  2012-07-22
# 2           2  2244389              SUC    2012  final 2nd leg  2012-08-29
# 3           3  2271112              DFB    2012    Round of 16  2012-12-18
# 4           4  2229332              DFL    2012          Final  2012-08-12
#
#    club_id  adversary_club_id  club_goals  adversary_club_goals  \
# 0      131                418           3                     2
# 1       58                498           3                     2
# 2      418                131           2                     1
# 3       48                 60           0                     1
# 4       27                 16           2                     1
#
#    club_position  adversary_club_position                        stadium  \
# ...

# %% [markdown]
# Adding the competitions names

# %%
games.loc[games.competition_code == 'BE1','competition_PN'] = 'Jupiler Pro League'
games.loc[games.competition_code == 'BESC','competition_PN'] = 'Belgian Supercup'
games.loc[games.competition_code == 'CDR','competition_PN'] = 'Copa del Rey'
games.loc[games.competition_code == 'CGB','competition_PN'] = 'EFL Cup'
games.loc[games.competition_code == 'CIT','competition_PN'] = 'Italy Cup'
games.loc[games.competition_code == 'CL','competition_PN'] = 'UEFA Champions League'
games.loc[games.competition_code == 'CLQ','competition_PN'] = 'UEFA Champions League Qualifiers'
games.loc[games.competition_code == 'DFB','competition_PN'] = 'DFB Pokal'
games.loc[games.competition_code == 'DFL','competition_PN'] = 'DFL Supercup'
games.loc[games.competition_code == 'DK1','competition_PN'] = 'Superligaen'
games.loc[games.competition_code == 'DKP','competition_PN'] = 'Sydbank Pokalen'
games.loc[games.competition_code == 'ECLQ','competition_PN'] = 'UEFA Europa Conference League Qualifiers'
games.loc[games.competition_code == 'EL','competition_PN'] = 'Europa League'
games.loc[games.competition_code == 'ELQ','competition_PN'] = 'Europa League Qualifiers'
games.loc[games.competition_code == 'ES1','competition_PN'] = 'La Liga'
games.loc[games.competition_code == 'FR1','competition_PN'] = 'Ligue 1'
games.loc[games.competition_code == 'FRCH','competition_PN'] = 'Trophee des Champions'
games.loc[games.competition_code == 'GB1','competition_PN'] = 'Premier League'
games.loc[games.competition_code == 'GBCS','competition_PN'] = 'Community Shield'
games.loc[games.competition_code == 'GR1','competition_PN'] = 'Super League 1'
games.loc[games.competition_code == 'GRP','competition_PN'] = 'Kypello  Elladas'
games.loc[games.competition_code == 'IT1','competition_PN'] = 'Serie A'
games.loc[games.competition_code == 'KLUB','competition_PN'] = 'FIFA Club World Cup'
games.loc[games.competition_code == 'L1','competition_PN'] = 'Bundesliga'
games.loc[games.competition_code == 'NL1','competition_PN'] = 'Eredivisie'
games.loc[games.competition_code == 'NLP','competition_PN'] = 'Toto KNVB Beker'
games.loc[games.competition_code == 'NLSC','competition_PN'] = 'Johan Cruijff Schaal'
games.loc[games.competition_code == 'PO1','competition_PN'] = 'Liga Portugal Bwin'
games.loc[games.competition_code == 'POCP','competition_PN'] = 'Allianz Cup'
games.loc[games.competition_code == 'POSU','competition_PN'] = 'Supertaca Candido de Oliveira'
games.loc[games.competition_code == 'RU1','competition_PN'] = 'Premier Liga'
games.loc[games.competition_code == 'RUP','competition_PN'] = 'Russian Cup'
games.loc[games.competition_code == 'RUSS','competition_PN'] = 'Russian Super Cup'
games.loc[games.competition_code == 'SC1','competition_PN'] = 'Scottish Premiership'
games.loc[games.competition_code == 'SCI','competition_PN'] = 'Supercoppa Italiana'
games.loc[games.competition_code == 'SFA','competition_PN'] = 'SFA Cup'
games.loc[games.competition_code == 'SUC','competition_PN'] = 'Supercopa'
games.loc[games.competition_code == 'TR1','competition_PN'] = 'Super Lig'
games.loc[games.competition_code == 'UKR1','competition_PN'] = 'Premier Liga'
games.loc[games.competition_code == 'UKRP','competition_PN'] = 'Ukrainian Cup'
games.loc[games.competition_code == 'UKRS','competition_PN'] = 'Ukrainian Super Cup'
games.loc[games.competition_code == 'USC','competition_PN'] = 'UEFA Super Cup'

display(games.head(10))
# Out:
#    Unnamed: 0  game_id competition_code  season               round  \
# 0           0  2244388              SUC    2012       final 1st leg
# 1           1  2219794             BESC    2011               Final
# 2           2  2244389              SUC    2012       final 2nd leg
# 3           3  2271112              DFB    2012         Round of 16
# 4           4  2229332              DFL    2012               Final
# 5           5  2258406             POCP    2012             Group D
# 6           6  2240525              NLP    2012         First Round
# 7           7  2240524              NLP    2012         First Round
# 8           8  2504433              NLP    2012         First Round
# 9           9  2254419              CDR    2012  First Round Replay
#
#          date  club_id  adversary_club_id  club_goals  adversary_club_goals  \
# 0  2012-08-22      131                418           3                     2
# ...

# %% [markdown]
# Exporting the csv

# %%
games.to_csv('games2.csv')
